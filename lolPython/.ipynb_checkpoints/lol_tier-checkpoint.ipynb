# %%
import urllib.request
import requests
import json

def search_by_username(input_name):
    apikey = 'RGAPI-f44ac3d2-ad1a-44e4-b75e-daf5a47f6437'
    basic_url = 'https://kr.api.riotgames.com'
    search_url = basic_url+'/lol/summoner/v4/summoners/by-name/{}?api_key={}'.format(input_name, apikey)

    data = requests.get(search_url)

    if data.status_code == 404:
        print("Name Error")

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

    else:
        print("Error")

    return

if __name__=='__main__':
    print("USERNAME?")
    name = input()
    search_by_username(name)
# Out:
# USERNAME?
# Hide on bush
# {'id': 'vkUap1dJSwc3OXG9hjPFvsmrSviJRBI9OoT1fZBxKce2ZQ', 'accountId': 't0PIZAox_Qfpk_jGLTRfGQsQVppJyLpswzYouGN7heA5', 'puuid': 'BFSRciIv-iTjQC8-iyywXT_qL5iK9FYUBBx_Z639PKpv20p6aWRGqGp3tK22cwdOLvwxGR3Bhuixiw', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1562755211000, 'summonerLevel': 235}

# %%
import urllib.request
import requests
import json

apikey = 'RGAPI-f44ac3d2-ad1a-44e4-b75e-daf5a47f6437'
basic_url = 'https://kr.api.riotgames.com'

def search_currentgame_by_userid(accountId):
    search_url = basic_url+'/lol/match/v4/matchlists/by-account/{}?api_key={}'.format(accountId, apikey)
    data = requests.get(search_url)

    if data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)

    else:
        print("Error")
        return

    return data

def search_by_username(input_name):
    search_url = basic_url+'/lol/summoner/v4/summoners/by-name/{}?api_key={}'.format(input_name, apikey)

    data = requests.get(search_url)

    # 없는 유저 입력
    if data.status_code == 404:
        print("Name Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

        userid = data.get('accountId')

    else:
        print("Error")
        return

    return userid

if __name__=='__main__':
    print("USERNAME?")
    name = input()
    userid = search_by_username(name)
    current_game_data = search_currentgame_by_userid(userid)
# Out:
# USERNAME?
# Hide on bush
# {'id': 'vkUap1dJSwc3OXG9hjPFvsmrSviJRBI9OoT1fZBxKce2ZQ', 'accountId': 't0PIZAox_Qfpk_jGLTRfGQsQVppJyLpswzYouGN7heA5', 'puuid': 'BFSRciIv-iTjQC8-iyywXT_qL5iK9FYUBBx_Z639PKpv20p6aWRGqGp3tK22cwdOLvwxGR3Bhuixiw', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1562755211000, 'summonerLevel': 235}

# %%
import requests
import json

apikey = 'RGAPI-f44ac3d2-ad1a-44e4-b75e-daf5a47f6437'
basic_url = 'https://kr.api.riotgames.com'

def get_gamers_info(game_data_lists):
    for single_game in game_data_lists:
        participants = single_game['participantIdentities']
        print(type(participants))
    pass

def get_game_info(matchid_list):
    data_lists = []

    for single_matchid in matchid_list:
        search_url = basic_url+'/lol/match/v4/matches/{}?api_key={}'.format(single_matchid, apikey)
        data = requests.get(search_url)


        if data.status_code == 200:
            data = requests.get(search_url).text
            data = json.loads(data)

            print("gameinfo :",data)

            game_data_dic = {}
            game_data_dic['gameDuration'] = data.get('gameDuration')
            game_data_dic['season'] = data.get('season')
            game_data_dic['teams'] = data.get('teams')
            game_data_dic['participants'] = data.get('participants')
            game_data_dic['participantIdentities'] = data.get('participantIdentities')
            data_lists.append(game_data_dic)

        else:
            print("Error")
            return

    print(data_lists)
    return data_lists


def get_user_tier(summonerid):
    search_url = basic_url+'/lol/league/v4/entries/by-summoner/{}?api_key={}'.format(summonerid, apikey)
    data = requests.get(search_url)

    if data.status_code == 200:
        data = requests.get(search_url).text

        # 언랭은 no data
        if len(data)>2:
            data = json.loads(data)[0]
            tier = data.get('tier')
            print(data)
            print(tier)

        else:
            print("UnRanked")
            return

    else:
        print("Error")
        return

    return tier


def get_gameIds_by_userid(accountId):
    search_url = basic_url+'/lol/match/v4/matchlists/by-account/{}?api_key={}'.format(accountId, apikey)
    data = requests.get(search_url)

    if data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

        matches = data.get('matches')
        gameIds = []
        for single_match in matches:
            gameIds.append(single_match.get('gameId'))

    else:
        print("Error")
        return

    return gameIds


def search_by_username(input_name):
    search_url = basic_url+'/lol/summoner/v4/summoners/by-name/{}?api_key={}'.format(input_name, apikey)

    data = requests.get(search_url)

    # 없는 유저 입력
    if data.status_code == 404:
        print("Name Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

        accountid = data.get('accountId')
        summonerid = data.get('id')

    else:
        print("Error")
        return

    return summonerid, accountid


if __name__=='__main__':
    print("USERNAME?")
    name = input()

    summonerid, accountid = search_by_username(name)
    #current_gameIds = get_gameIds_by_userid(accountid)
    tier = get_user_tier(summonerid)
    #game_data_lists = get_game_info(current_gameIds)
    #get_gamers_info(game_data_lists)
# Out:
# USERNAME?
# Hide on bush
# {'id': 'vkUap1dJSwc3OXG9hjPFvsmrSviJRBI9OoT1fZBxKce2ZQ', 'accountId': 't0PIZAox_Qfpk_jGLTRfGQsQVppJyLpswzYouGN7heA5', 'puuid': 'BFSRciIv-iTjQC8-iyywXT_qL5iK9FYUBBx_Z639PKpv20p6aWRGqGp3tK22cwdOLvwxGR3Bhuixiw', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1562755211000, 'summonerLevel': 235}
# {'leagueId': 'ba73b86b-97c9-3dfc-856e-88777fec7e56', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'CHALLENGER', 'rank': 'I', 'summonerId': 'vkUap1dJSwc3OXG9hjPFvsmrSviJRBI9OoT1fZBxKce2ZQ', 'summonerName': 'Hide on bush', 'leaguePoints': 801, 'wins': 331, 'losses': 337, 'veteran': True, 'inactive': False, 'freshBlood': False, 'hotStreak': True}
# CHALLENGER

# %%
import requests
import json

apikey = 'RGAPI-f44ac3d2-ad1a-44e4-b75e-daf5a47f6437'
basic_url = 'https://kr.api.riotgames.com'




def get_user_tier(summonerid):
    search_url = basic_url+'/lol/league/v4/entries/by-summoner/{}?api_key={}'.format(summonerid, apikey)
    data = requests.get(search_url)

    if data.status_code == 200:
        data = requests.get(search_url).text

        # 언랭은 no data
        if len(data)>2:
            data = json.loads(data)[0]
            tier = data.get('tier')
            print(data)
            print(tier)

        else:
            print("UnRanked")
            return

    else:
        print("Error")
        return

    return tier


#챌에서만 큐 검색하면 전체출력
def search_tier(tier):
    search_url = basic_url+'/lol/league/v4/challengerleagues/by-queue/{}?api_key={}'.format(tier, apikey)

    data = requests.get(search_url)

    # 없는 티어 입력
    if data.status_code == 404:
        print("Tier Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

        tiername = data.get('tier')
        summonerid = data.get('summonerName')

    else:
        print("Error")
        return

    return summonerid

    

if __name__=='__main__':
    print("TIER?")
    tier = input()

    #summonerid, accountid = search_by_username(name)
    #current_gameIds = get_gameIds_by_userid(accountid)
    search_tier(tier)
    #game_data_lists = get_game_info(current_gameIds)
    #get_gamers_info(game_data_lists)
    #leagueId(name)
# Out:
# TIER?
# DIAMOND
# Error

# %%
def search_by_username(input_name):
    search_url = basic_url+'/lol/summoner/v4/summoners/by-name/{}?api_key={}'.format(input_name, apikey)

    data = requests.get(search_url)

    # 없는 유저 입력
    if data.status_code == 404:
        print("Name Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

        accountid = data.get('accountId')
        summonerid = data.get('id')

    else:
        print("Error")
        return

    return summonerid


def leagueId(enname):
    search_url = basic_url+'/lol/league/v4/entries/by-summoner/{}?api_key={}'.format(enname, apikey)

    data = requests.get(search_url)
    # 없는 유저 입력
    if data.status_code == 404:
        print("Name Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)
        print(data)

        leagueId = data.get('leagueId')

    else:
        print("Error")
        return
    
    return leagueId

if __name__=='__main__':
    print("NAME?")
    name = input()
    
    summonerid = search_by_username(name)
    leagueId(summonerid)
# Out:
# NAME?
# Hide on bush
# {'id': 'vkUap1dJSwc3OXG9hjPFvsmrSviJRBI9OoT1fZBxKce2ZQ', 'accountId': 't0PIZAox_Qfpk_jGLTRfGQsQVppJyLpswzYouGN7heA5', 'puuid': 'BFSRciIv-iTjQC8-iyywXT_qL5iK9FYUBBx_Z639PKpv20p6aWRGqGp3tK22cwdOLvwxGR3Bhuixiw', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1562755211000, 'summonerLevel': 235}
# [{'leagueId': 'ba73b86b-97c9-3dfc-856e-88777fec7e56', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'CHALLENGER', 'rank': 'I', 'summonerId': 'vkUap1dJSwc3OXG9hjPFvsmrSviJRBI9OoT1fZBxKce2ZQ', 'summonerName': 'Hide on bush', 'leaguePoints': 801, 'wins': 331, 'losses': 337, 'veteran': True, 'inactive': False, 'freshBlood': False, 'hotStreak': True}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-3be749c74c88> in <module>
#      51
#      52     summonerid = search_by_username(name)
# ---> 53     leagueId(summonerid)
#
# <ipython-input-8-3be749c74c88> in leagueId(enname)
#      38         print(data)
#      39
# ---> 40         leagueId = data.get('leagueId')
#      41
#      42     else:
#
# AttributeError: 'list' object has no attribute 'get'

# %%
from operator import itemgetter

challenger='ba73b86b-97c9-3dfc-856e-88777fec7e56'
grandmater='b82a4a63-6fe0-34c1-96c5-bd9a7b8b8201'
master='02b21acc-7155-3e13-a409-609de4846bd3'
diamond='4beff060-55dd-11e9-b8dd-c81f66e3887d'
platinum='a9a6a5f0-2b80-11e9-8f87-c81f66e3887d'
gold='de6b8900-1f68-11e9-9e9d-c81f66e41892'
silver='841f3260-1fa6-11e9-a8a8-f8bc12422f38'
bronze='ad67fc30-33ae-11e9-b963-f8bc12426294'
iron='b02e6430-209f-11e9-9584-f8bc12422f38'

#masterNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(master, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
masterNum=len(entries)

#diaNum=0
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(diamond, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
diaNum=len(entries)

#plaNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(platinum, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
plaNum=len(entries)

#goldNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(gold, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
goldNum=len(entries)

#silverNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(silver, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
silverNum=len(entries)

#bronzeNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(bronze, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
bronzeNum=len(entries)

#ironNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(iron, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
ironNum=len(entries)



def allPlayer(leagueId):

    search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(leagueId, apikey)
    data = requests.get(search_url)
    
    if data.status_code == 404:
        print("Tier Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        #print(data)
        data = json.loads(data)
        #print(data)

        #tiername = data.get('tier')
        entries = data.get('entries')
        #summonerName = data.get('summonerName')
        #summonerName = entries[i].get('summonerName')
        

    else:
        print("Error")
        return

    #lp 기준으로 높은사람순으로 정렬 - 랭크표시
    entries = sorted(entries, key=itemgetter('leaguePoints'), reverse=True)
    num=1
    
    if leagueId=='b82a4a63-6fe0-34c1-96c5-bd9a7b8b8201': #그마
        num=num+300
    elif leagueId=='02b21acc-7155-3e13-a409-609de4846bd3': #마스터
        num=num+1000
    elif leagueId=='4beff060-55dd-11e9-b8dd-c81f66e3887d': #다이아
        num=num+1000+masterNum
    elif leagueId=='a9a6a5f0-2b80-11e9-8f87-c81f66e3887d': #플레
        num=num+1000+masterNum+diaNum
    elif leagueId=='de6b8900-1f68-11e9-9e9d-c81f66e41892': #골드
        num=num+1000+masterNum+diaNum+plaNum
    elif leagueId=='841f3260-1fa6-11e9-a8a8-f8bc12422f38': #실버
        num=num+1000+masterNum+diaNum+plaNum+goldNum
    elif leagueId=='ad67fc30-33ae-11e9-b963-f8bc12426294': #브론즈
        num=num+1000+masterNum+diaNum+plaNum+goldNum+silverNum
    elif leagueId=='b02e6430-209f-11e9-9584-f8bc12422f38': #아이언
        num=num+1000+masterNum+diaNum+plaNum+goldNum+silverNum+bronzeNum
    #출력
    for i in entries:
        print(num,'.',i['summonerName'])
        num=num+1
    
    

if __name__=='__main__':
    print("LEAGUE NAME?")
    leagueId = input()
    
    #summonerid = search_by_username(name)
    #leagueId = leagueId(summonerid)
    allPlayer(leagueId)
# Out:
# LEAGUE NAME?
# DIAMOND
# Error

# %%
def allPlayer(tier):
    num=1
    search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/{}/{}?api_key={}'.format(tier,division, apikey)
    data = requests.get(search_url)
    
    if data.status_code == 404:
        print("Tier Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        #print(data)
        data = json.loads(data)
        #print(data)

        tiername = data.get('tier')
        entries = data.get('entries')
        #summonerName = data.get('summonerName')
        #summonerName = entries[i].get('summonerName')
        #for i in entries:
        #for value in data:
            #print(num,i['summonerName'])
            #num=num+1
        print(data['tier'])
        

    else:
        print("Error")
        return
    
if __name__=='__main__':
    print("tier?")
    tier = input()
    print("division?")
    division = input()
    
    #summonerid = search_by_username(name)
    #leagueId = leagueId(summonerid)
    allPlayer(tier)
# Out:
# tier?
# DIAMOND
# division?
# I
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-89814af4517d> in <module>
#      37     #summonerid = search_by_username(name)
#      38     #leagueId = leagueId(summonerid)
# ---> 39     allPlayer(tier)
#
# <ipython-input-10-89814af4517d> in allPlayer(tier)
#      14         #print(data)
#      15
# ---> 16         tiername = data.get('tier')
#      17         entries = data.get('entries')
#      18         #summonerName = data.get('summonerName')
#
# AttributeError: 'list' object has no attribute 'get'

# %%
def allPlayer(tier):
    num=1
    search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/{}/{}?api_key={}'.format(tier,division, apikey)
    data = requests.get(search_url)
    
    if data.status_code == 404:
        print("Tier Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)

        #lp 기준으로 높은사람순으로 정렬
        data = sorted(data, key=itemgetter('leaguePoints'), reverse=True)
        for i in data:
            print(i['summonerName'])
        

    else:
        print("Error")
        return
    
if __name__=='__main__':
    print("tier?")
    tier = input()
    print("division?")
    division = input()
    
    #summonerid = search_by_username(name)
    #leagueId = leagueId(summonerid)
    allPlayer(tier)
# Out:
# tier?
# DIAMOND
# division?
# I
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8246e0a2034b> in <module>
#      30     #summonerid = search_by_username(name)
#      31     #leagueId = leagueId(summonerid)
# ---> 32     allPlayer(tier)
#
# <ipython-input-2-8246e0a2034b> in allPlayer(tier)
#       1 def allPlayer(tier):
#       2     num=1
# ----> 3     search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/{}/{}?api_key={}'.format(tier,division, apikey)
#       4     data = requests.get(search_url)
#       5
#
# NameError: name 'basic_url' is not defined

# %%
#masterNum
search_url = basic_url+'/lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5?api_key={}'.format(apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
masterNum=len(entries)+1
print(masterNum)

#diaNum
search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/DIAMOND/I?api_key={}'.format(apikey)
data = requests.get(search_url)
dia1Num=1
data = requests.get(search_url).text
data = json.loads(data)
for i in data:
    #print(i['summonerName'])
    dia1Num=dia1Num+1
print(dia1Num)

search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/DIAMOND/II?api_key={}'.format(apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
dia2Num=len(data)

search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/DIAMOND/III?api_key={}'.format(apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
dia3Num=len(data)

search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/DIAMOND/IV?api_key={}'.format(apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
dia4Num=len(data)

diaNum=dia1Num+dia2Num+dia3Num+dia4Num

#plaNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(platinum, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
plaNum=len(entries)

#goldNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(gold, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
goldNum=len(entries)

#silverNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(silver, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
silverNum=len(entries)

#bronzeNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(bronze, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
bronzeNum=len(entries)

#ironNum
search_url = basic_url+'/lol/league/v4/leagues/{}?api_key={}'.format(iron, apikey)
data = requests.get(search_url)

data = requests.get(search_url).text
data = json.loads(data)
entries=data.get('entries')
ironNum=len(entries)

def allPlayer(tier):
    
    
    
    search_url = basic_url+'/lol/league/v4/entries/RANKED_SOLO_5x5/{}/{}?api_key={}'.format(tier,division, apikey)
    data = requests.get(search_url)
    
    if data.status_code == 404:
        print("Tier Error")
        return

    elif data.status_code == 200:
        data = requests.get(search_url).text
        data = json.loads(data)

        #lp 기준으로 높은사람순으로 정렬
        data = sorted(data, key=itemgetter('leaguePoints'), reverse=True)
        
        
        num=1
        if tier=='GRANDMASTER': #그마
            num=num+300
        elif leagueId=='MASTER': #마스터
            num=num+1000
        elif leagueId=='DIAMOND':#다이아
            if division=='I':
                num=num+1000+masterNum
            elif division=='II':
                num=num+1000+masterNum+dia1Num
            elif division=='III':
                num=num+1000+masterNum+dia1Num+dia2Num
            elif division=='IV':
                num=num+1000+masterNum+dia1Num+dia2Num+dia3Num
        
        
        for i in data:
            print(num,i['summonerName'])
            num=num+1
        

    else:
        print("Error")
        return
    
if __name__=='__main__':
    print("tier?")
    tier = input()
    print("division?")
    division = input()
    
    allPlayer(tier)
# Out:
# 1480
# 206
# tier?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-3b553ed5d65e> in <module>
#     134 if __name__=='__main__':
#     135     print("tier?")
# --> 136     tier = input()
#     137     print("division?")
#     138     division = input()
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %%
import urllib.request
import requests
import json
from operator import itemgetter

apikey = 'RGAPI-9ef88465-d01a-4a13-b662-256e1f5064b9'
basic_url = 'https://kr.api.riotgames.com'

search_url = basic_url+'/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={}'.format(apikey)

data = requests.get(search_url).text
data = json.loads(data)
#print(data)

entries=data.get('entries')
#print(entries)

entries = sorted(entries, key=itemgetter('leaguePoints'), reverse=True)
num=1

for i in entries:
    #print(i)
    summonerName=i.get('summonerName')
    print(num,summonerName)
    num=num+1
# Out:
# 1 타 잔
# 2 Cuzz
# 3 인디언식 기우제
# 4 DWG BeryL
# 5 Ucal
# 6 KZ Keria
# 7 DWG ShowMaker
# 8 LNG Light
# 9 말할창천좀란말할
# 10 JUGKlNG
# 11 사자형뚜껑 향로
# 12 always confident
# 13 Gen G Bonnie
# 14 밀레니엄베이비
# 15 호잇이
# 16 SKT T1 Clid
# 17 Kanavi
# 18 obgz
# 19 Baki
# 20 첫 새싹
# 21 아라가키 유이
# 22 Gen G Ruler
# 23 SKT T1 Teddy
# 24 MCPC
# 25 SBNA
# 26 Jin Air Kellin
# 27 오리지널찰떡쿠키
# 28 Gen G Peanut
# 29 오뚜기3분미트볼
# 30 Dont Stop Me XD
# 31 읽씹맨
# 32 Aind
# 33 담원 쇼메이커
# 34 yzdzh
# 35 KZ Deft0
# 36 T2K2T2K2
# 37 DWG Canyon
# 38 ZOEKlNG
# 39 pick jg
# 40 하나의 풍경
# 41 해강고 원딜
# 42 SKT T1 Kaan
# 43 KT 비디디
# 44 Lehends
# 45 XxXxXxXxMax
# 46 KZ Rascal
# 47 SKT T1 Haru
# 48 찢어진 책페이지
# 49 Tomorrow comes
# 50 엘 림
# 51 xxxxxxi
# 52 DBBBBBBBBB
# 53 인생파도나는서퍼
# 54 월화수금토목
# 55 엉덩국 갱승제로
# 56 난 질수없다
# 57 yeqiL7
# 58 SKT T1 Kuri2
# 59 하루 그림자2
# 60 6고블린3메이지
# 61 Gen G Kuzan2
# 62 guoke
# 63 삼중인격권장게임
# 64 날뜩한 칼
# 65 qpalzmwoaj
# 66 SKT T1 Gumayusl
# 67 야생을죽이기위해
# 68 Lehends heir
# 69 SN Ezsyboom
# 70 Retired sup
# 71 강인한방패 애디
# 72 MIDKlNG
# 73 Clever7
# 74 Morgan5358
# 75 쿠 리
# 76 둥근해가떡섭니다
# 77 다 같이 잘해보죠
# 78 마스터가기싫어요
# 79 bfwhlqqnl
# 80 Destiny
# 81 마앗 좀 볼까
# 82 낮잠의신
# 83 Im doing
# 84 나는이재능이없다
# 85 BLG ADD
# 86 통닭빌런
# 87 SANDBOX Lonely
# 88 이 차가 식기전에
# 89 Gen G Roach
# 90 Lunatic Reisenn
# 91 조이보다잘재음
# 92 의정부 송유준
# 93 밀레니엄베이베
# 94 미니언놓치지말자
# 95 우르뜨rider
# 96 아마존강유역주민
# 97 Ionely
# 98 모건오삼오팔
# 99 DWG Punch
# 100 slzmspdla
# 101 Khalis
# 102 Christopher N
# 103 SANDBOX OnFleek
# 104 skt t1 le0
# 105 Iove camille
# 106 Pz ZZang
# 107 Gen G cuvee
# 108 real gankster
# 109 사 용 수
# 110 하루 그림자
# 111 Naehyun
# 112 단군의청춘부재
# 113 zenganiu
# 114 사랑해 김린아
# 115 l3est16
# 116 박투신
# 117 Wesuk1laye
# 118 SKT T1 Crazy
# 119 KINGAD
# 120 Hide on bush
# 121 More than lovers
# 122 저튜브보고올렸어
# 123 욕받이원딜러1
# 124 아깝다아깝다
# 125 12401240
# 126 요플래
# 127 SANDBOX Hollow
# 128 Need time
# 129 지 연 증
# 130 HLE Bmav
# 131 율천고 펀치라인
# 132 korean standard
# 133 MapSSi
# 134 사스갓지지
# 135 메 끠
# 136 잠은허송시간
# 137 asdasdasfsdfas
# 138 DEULDEUL
# 139 LNG JG
# 140 VSG reM
# 141 I AM IRON4 SUP
# 142 APK Cover
# 143 롤오브레전드1234
# 144 Tesnuguri
# 145 Isildur1
# 146 뭐거북이처음보냐
# 147 TnTttttttttttttt
# 148 릴러말즈 야망
# 149 눈가루 OwO
# 150 쭌 베
# 151 Jin Air Route
# 152 너를비웃다
# 153 Kloen
# 154 WE 77
# 155 Gen G Asper
# 156 HLE MooJin
# 157 pupuiqoaix
# 158 승지부기
# 159 나경누나 이쁘다
# 160 Winners Karas
# 161 내겐 문제가 많아
# 162 zxczxczxczxzx
# 163 VSG Veritas
# 164 알아요나못해요
# 165 벗방의귀제정해성
# 166 김9거
# 167 AOTG
# 168 HLE Thal
# 169 deokdam
# 170 ANG TV
# 171 이길게 더이길게
# 172 bgch
# 173 버기해적단 버기
# 174 Sora2
# 175 M1nit
# 176 SKT T1 GGori
# 177 Afreeca Spirit
# 178 daDDak과소통안함
# 179 소비러와 존잘님
# 180 qiaqia
# 181 나는 준일하다
# 182 이주한1
# 183 Reborn1
# 184 zhenkeyihenqiang
# 185 TS cool
# 186 DoRun
# 187 N4talie
# 188 determine
# 189 SKT T1 Ted
# 190 JAYCEKING
# 191 pi9
# 192 아이들대박
# 193 양양아기
# 194 HLE S0Hwan
# 195 whisper snow
# 196 끝나지 않은 전투
# 197 zxcvcvbnm
# 198 VSG Ruby
# 199 견 백
# 200 엉덩국 갱승제로2
# 201 VSG 리리스
# 202 스너우 꽃
# 203 daydayupup
# 204 FIark
# 205 sweetgirll
# 206 금동약사여래입상
# 207 진짜멍뭉이
# 208 냥잇이
# 209 하루 그림자1
# 210 허징어링
# 211 cepted
# 212 ILoveYoul
# 213 캐 인
# 214 실버퀸 박옥자
# 215 Jln Air Grace
# 216 정화 유체화1
# 217 iboy2
# 218 1345678902
# 219 못먹겟어삼각김밥
# 220 summertime
# 221 Triple try
# 222 LGD YuuKi
# 223 Twitch익산누누
# 224 FW SUP
# 225 Swordart777
# 226 캡스 fan
# 227 금똥왁왁
# 228 시러맨바보
# 229 hf ghkyu2
# 230 구마유시
# 231 bad guy0
# 232 일랜시아1
# 233 Furuhashi Fumino
# 234 Jin Air Nova
# 235 SKT T1 Closer
# 236 vmajnjkdqhwey
# 237 IlllllIIIII
# 238 BRION FATE
# 239 Kawayi9
# 240 소중함을잊지말자
# 241 만대면 안지
# 242 Find My AD
# 243 므라기2
# 244 현실와꾸강동원
# 245 곰토끼개고양이
# 246 cherish1003
# 247 스떠콘유
# 248 V1ns
# 249 Tired of oneself
# 250 골드퀸박옥자
# 251 사랑했던날
# 252 하이드
# 253 이미니언다먹자
# 254 lemonade9
# 255 종학it
# 256 군밤갓
# 257 4seidon
# 258 외쳐주유소갓라카
# 259 병권좌
# 260 Nu99et
# 261 뽀오뽀오
# 262 우빡이1호
# 263 YiQiKuaile
# 264 CyberangeI
# 265 KZ Seonbi R
# 266 갱오면게속죽음
# 267 FFANCY
# 268 Singapore Sky
# 269 bullpagen
# 270 BJ서준석사생팬
# 271 탐 신
# 272 기묘기묘
# 273 Endurance
# 274 Heart
# 275 진짜졸린다
# 276 xhwwlpybz
# 277 환심환심
# 278 5Kid
# 279 클린아이디
# 280 칼날부리믜 반격
# 281 6암살자4닌자
# 282 shame shame
# 283 Top op line
# 284 love camIIe
# 285 페이커 fan
# 286 xzvasdlqwras
# 287 Choi YeNa 99
# 288 hfcc
# 289 riseee
# 290 힘내암살의 왕
# 291 Proud LEE
# 292 기풍료
# 293 KZ Pleata R
# 294 happy   game
# 295 귀여운 현우
# 296 이도류
# 297 Climbing High
# 298 SeaYouGoneTenYeT
# 299 플로리즈
# 300 숨쉬세요라이너들

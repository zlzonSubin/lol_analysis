# %% [markdown]
# # 마스터 D점멸? F점멸?
# ### D점멸은 { 'spell1Id' : 4 }  F점멸은 { 'spell2Id' : 4 }

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_CHALLENGER" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 24, 'spell1Id': 4, 'spell2Id': 12, 'stats': {'participantId': 1, 'win': True, 'item0': 1055, 'item1': 2033, 'item2': 3078, 'item3': 3047, 'item4': 1036, 'item5': 0, 'item6': 3340, 'kills': 1, 'deaths': 1, 'assists': 3, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'killingSprees': 0, 'longestTimeSpentLiving': 392, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 57234, 'magicDamageDealt': 9899, 'physicalDamageDealt': 44551, 'trueDamageDealt': 2784, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 4216, 'magicDamageDealtToChampions': 1252, 'physicalDamageDealtToChampions': 2963, 'trueDamageDealtToChampions': 0, 'totalHeal': 925, 'totalUnitsHealed': 1, 'damageSelfMitigated': 3635, 'damageDealtToObjectives': 11966, 'damageDealtToTurrets': 5909, 'visionScore': 9, 'timeCCingOthers': 3, 'totalDamageTaken': 6931, 'magicalDamageTaken': 2374, 'physicalDamageTaken': 4500, 'trueDamageTaken': 57, 'goldEarned': 6018, 'goldSpent': 5908, 'turretKills': 2, 'inhibitorKills': 0, 'totalMinionsKilled': 96, 'neutralMinionsKilled': 1, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 64, 'champLevel': 10, 'visionWardsBoughtInGame': 1, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 5, 'wardsKilled': 1, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8437, 'perk0Var1': 256, 'perk0Var2': 170, 'perk0Var3': 0, 'perk1': 8446, 'perk1Var1': 1116, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8473, 'perk2Var1': 232, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8451, 'perk3Var1': 109, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8304, 'perk4Var1': 10, 'perk4Var2': 3, 'perk4Var3': 0, 'perk5': 8352, 'perk5Var1': 166, 'perk5Var2': 812, 'perk5Var3': 440, 'perkPrimaryStyle': 8400, 'perkSubStyle': 8300, 'statPerk0': 5008, 'statPerk1': 5008, 'statPerk2': 5002}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'0-10': 5.7}, 'xpPerMinDeltas': {'0-10': 407.5}, 'goldPerMinDeltas': {'0-10': 287.20000000000005}, 'csDiffPerMinDeltas': {'0-10': -0.5799999999999998}, 'xpDiffPerMinDeltas': {'0-10': 41.76000000000003}, 'damageTakenPerMinDeltas': {'0-10': 508.6}, 'damageTakenDiffPerMinDeltas': {'0-10': 6.779999999999973}, 'role': 'DUO_SUPPORT', 'lane': 'NONE'}}, {'participantId': 2, 'teamId': 100, 'championId': 84, 'spell1Id': 14, 'spell2Id': 4, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 2, 'win': True, 'item0': 3146, 'item1': 2031, 'item2': 3191, 'item3': 2055, 'item4': 1054, 'item5': 3020, 'item6': 3340, 'kills': 4, 'deaths': 1, 'assists': 3, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 2, 'longestTimeSpentLiving': 562, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 48055, 'magicDamageDealt': 38017, 'physicalDamageDealt': 8158, 'trueDamageDealt': 1880, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 6743, 'magicDamageDealtToChampions': 4776, 'physicalDamageDealtToChampions': 1700, 'trueDamageDealtToChampions': 266, 'totalHeal': 1536, 'totalUnitsHealed': 1, 'damageSelfMitigated': 5153, 'damageDealtToObjectives': 1086, 'damageDealtToTurrets': 1086, 'visionScore': 13, 'timeCCingOthers': 2, 'totalDamageTaken': 8440, 'magicalDamageTaken': 1546, 'physicalDamageTaken': 6544, 'trueDamageTaken': 349, 'goldEarned': 6294, 'goldSpent': 6250, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 105, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 31, 'champLevel': 11, 'vi ...
# D점멸쓰는사람 5082
# F점멸쓰는사람 20328

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_GRANDMASTER" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 25, 'spell1Id': 12, 'spell2Id': 4, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 1, 'win': False, 'item0': 3030, 'item1': 2055, 'item2': 2421, 'item3': 3020, 'item4': 0, 'item5': 1056, 'item6': 3363, 'kills': 2, 'deaths': 5, 'assists': 1, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'killingSprees': 0, 'longestTimeSpentLiving': 484, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 43151, 'magicDamageDealt': 34253, 'physicalDamageDealt': 6293, 'trueDamageDealt': 2605, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 6253, 'magicDamageDealtToChampions': 6103, 'physicalDamageDealtToChampions': 149, 'trueDamageDealtToChampions': 0, 'totalHeal': 1642, 'totalUnitsHealed': 1, 'damageSelfMitigated': 4785, 'damageDealtToObjectives': 326, 'damageDealtToTurrets': 326, 'visionScore': 14, 'timeCCingOthers': 43, 'totalDamageTaken': 11366, 'magicalDamageTaken': 5122, 'physicalDamageTaken': 5243, 'trueDamageTaken': 1000, 'goldEarned': 5300, 'goldSpent': 5125, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 88, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 102, 'champLevel': 10, 'visionWardsBoughtInGame': 3, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 6, 'wardsKilled': 2, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8351, 'perk0Var1': 3, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8304, 'perk1Var1': 10, 'perk1Var2': 3, 'perk1Var3': 0, 'perk2': 8345, 'perk2Var1': 4, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8347, 'perk3Var1': 0, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8226, 'perk4Var1': 250, 'perk4Var2': 449, 'perk4Var3': 0, 'perk5': 8233, 'perk5Var1': 8, 'perk5Var2': 40, 'perk5Var3': 0, 'perkPrimaryStyle': 8300, 'perkSubStyle': 8200, 'statPerk0': 5008, 'statPerk1': 5008, 'statPerk2': 5002}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'0-10': 4.4}, 'xpPerMinDeltas': {'0-10': 339.6}, 'goldPerMinDeltas': {'0-10': 230.3}, 'csDiffPerMinDeltas': {'0-10': -0.5000000000000004}, 'xpDiffPerMinDeltas': {'0-10': -27.19999999999999}, 'damageTakenPerMinDeltas': {'0-10': 479.79999999999995}, 'damageTakenDiffPerMinDeltas': {'0-10': 81.70000000000002}, 'role': 'DUO_SUPPORT', 'lane': 'NONE'}}, {'participantId': 2, 'teamId': 100, 'championId': 34, 'spell1Id': 14, 'spell2Id': 4, 'stats': {'participantId': 2, 'win': False, 'item0': 2033, 'item1': 1033, 'item2': 3027, 'item3': 1001, 'item4': 3070, 'item5': 0, 'item6': 3363, 'kills': 2, 'deaths': 0, 'assists': 2, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 0, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 41501, 'magicDamageDealt': 34268, 'physicalDamageDealt': 6406, 'trueDamageDealt': 826, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 7994, 'magicDamageDealtToChampions': 6083, 'physicalDamageDealtToChampions': 1113, 'trueDamageDealtToChampions': 797, 'totalHeal': 466, 'totalUnitsHealed': 1, 'damageSelfMitigated': 2723, 'damageDealtToObjectives': 0, 'damageDealtToTurrets': 0, 'visionScore': 16, 'timeCCingOthers': 27, 'totalDamageTaken': 6991, 'magicalDamageTaken': 2555, 'physicalDamageTaken': 4187, 'trueDamageTaken': 248, 'goldEarned': 5364, 'goldSpent': 5000, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 98, 'neutralMinionsKilled': 4, 'neutralMinionsKilledTeamJungle': 4, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrow ...
# D점멸쓰는사람 3666
# F점멸쓰는사람 32994

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_MASTER" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 119, 'spell1Id': 7, 'spell2Id': 4, 'stats': {'participantId': 1, 'win': True, 'item0': 1054, 'item1': 3072, 'item2': 3812, 'item3': 3031, 'item4': 3047, 'item5': 0, 'item6': 3363, 'kills': 5, 'deaths': 4, 'assists': 4, 'largestKillingSpree': 4, 'largestMultiKill': 2, 'killingSprees': 1, 'longestTimeSpentLiving': 540, 'doubleKills': 1, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 138752, 'magicDamageDealt': 35, 'physicalDamageDealt': 127736, 'trueDamageDealt': 10980, 'largestCriticalStrike': 901, 'totalDamageDealtToChampions': 11976, 'magicDamageDealtToChampions': 35, 'physicalDamageDealtToChampions': 11940, 'trueDamageDealtToChampions': 0, 'totalHeal': 2013, 'totalUnitsHealed': 3, 'damageSelfMitigated': 14933, 'damageDealtToObjectives': 7501, 'damageDealtToTurrets': 4335, 'visionScore': 19, 'timeCCingOthers': 3, 'totalDamageTaken': 13238, 'magicalDamageTaken': 3499, 'physicalDamageTaken': 8296, 'trueDamageTaken': 1441, 'goldEarned': 12487, 'goldSpent': 12210, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 220, 'neutralMinionsKilled': 4, 'neutralMinionsKilledTeamJungle': 4, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 26, 'champLevel': 13, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 7, 'wardsKilled': 5, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8005, 'perk0Var1': 654, 'perk0Var2': 514, 'perk0Var3': 140, 'perk1': 9111, 'perk1Var1': 150, 'perk1Var2': 180, 'perk1Var3': 0, 'perk2': 9103, 'perk2Var1': 24, 'perk2Var2': 50, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 284, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8304, 'perk4Var1': 10, 'perk4Var2': 3, 'perk4Var3': 0, 'perk5': 8345, 'perk5Var1': 4, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8300, 'statPerk0': 5005, 'statPerk1': 5008, 'statPerk2': 5002}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'10-20': 9, '0-10': 8.1}, 'xpPerMinDeltas': {'10-20': 485.29999999999995, '0-10': 300.1}, 'goldPerMinDeltas': {'10-20': 517.2, '0-10': 260.2}, 'csDiffPerMinDeltas': {'10-20': -0.40000000000000036, '0-10': 0.7}, 'xpDiffPerMinDeltas': {'10-20': -32.349999999999966, '0-10': 6.799999999999983}, 'damageTakenPerMinDeltas': {'10-20': 631.4, '0-10': 393.59999999999997}, 'damageTakenDiffPerMinDeltas': {'10-20': 37.24999999999997, '0-10': 116.84999999999998}, 'role': 'DUO_CARRY', 'lane': 'BOTTOM'}}, {'participantId': 2, 'teamId': 100, 'championId': 126, 'spell1Id': 12, 'spell2Id': 4, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 2, 'win': True, 'item0': 2033, 'item1': 3142, 'item2': 3042, 'item3': 2055, 'item4': 3111, 'item5': 3147, 'item6': 3340, 'kills': 4, 'deaths': 2, 'assists': 4, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 793, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 134287, 'magicDamageDealt': 10674, 'physicalDamageDealt': 115125, 'trueDamageDealt': 8488, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 16598, 'magicDamageDealtToChampions': 3387, 'physicalDamageDealtToChampions': 13051, 'trueDamageDealtToChampions': 160, 'totalHeal': 2729, 'totalUnitsHealed': 1, 'damageSelfMitigated': 6282, 'damageDealtToObjectives': 20942, 'damageDealtToTurrets': 7919, 'visionScore': 23, 'timeCCingOthers': 6, 'totalDamageTaken': 10505, 'magicalDamageTaken': 4242, 'physicalDamageTaken': 5473, 'trueDamageTaken': 789, 'goldEarned': 11025, 'goldSpent': 10100 ...
# D점멸쓰는사람 5610
# F점멸쓰는사람 13090

# %%
os.listdir('/Users/kangsubin/201511078/lol/lolPython/gamedata')
# Out:
# ['ZOEKlNG',
#  'ehdnal456',
#  'dont_smile_at_me',
#  'bfwhlqqnl',
#  'The_Pino',
#  'LuckyBarrier',
#  'passion99',
#  'Iove_camille',
#  '콩고녀',
#  'mei_you_da_long',
#  'bobbyrok',
#  'CGA_ArT',
#  'SANDBOX_Dove',
#  'CharmingBox',
#  'obgz',
#  '.DS_Store',
#  'Always_Praying',
#  'Triple_try',
#  'Jin_Air_CheonGo',
#  'Chasy',
#  'Ucal',
#  'SBNA',
#  'TeamBOK',
#  'HLE_Merry',
#  'Feou',
#  'Aliez_2019',
#  'YUSUNGJIN',
#  'Jin_Air_Route',
#  'Kloen',
#  'PenBen',
#  'Ghent',
#  'KingTaePark',
#  '우유맛크림',
#  'Crying',
#  'always_confident',
#  'd1gi',
#  '롤오랜만이에요',
#  'love_camIIe',
#  'Aind',
#  'Pz_ZZang',
#  'Winners_Karas',
#  'ohnimeel',
#  'TS_cool',
#  'SUPERB_TEAM',
#  'Jebudo',
#  'teemo_trauma',
#  'Uehara_Akali',
#  'Dondalran_Mila',
#  'Tselin',
#  'Monster_king',
#  'SKT_T1_Teddy',
#  'mamasalasa',
#  'daydayupup',
#  'NeverFY',
#  'yico1335225377',
#  'More_than_lovers',
#  'SANDBOX_Poffer',
#  'n_sile_xuema',
#  'Baki',
#  'Unbearable',
#  'Kanavi',
#  'Lunatic_Reisenn',
#  'LNG_Light',
#  'Prescoz',
#  'Gen_G_Roach',
#  'llllIIIIIll',
#  'MapSSi',
#  'Gen_G_Ruler',
#  'U_Rooto',
#  'DWG_BeryL',
#  'D1ngchenyu',
#  'Singapore_Sky',
#  '잘생긴_타잔',
#  'HLE_Sangyoon',
#  'from_the_sniper',
#  'pick_jg',
#  'JUGKlNG',
#  'Nu99et',
#  'Eimahc',
#  'LoL_leaderda',
#  'huni_is_free',
#  'li_gua_er_qu',
#  'lonely',
#  'lemonade9',
#  'Klassic',
#  'isoprophylene',
#  'Destiny',
#  'rqewadfsx',
#  'PPPPzzzz',
#  'Gen_G_Peanut',
#  'liu_yi_qi',
#  'XxXxXxXxMax',
#  'korean_standard',
#  'moment_moving',
#  'SKT_T1_Clid',
#  'MIDKlNG',
#  'KZ_Keria',
#  'DWG_Punch',
#  'MosquetaireR',
#  'Arnber_God',
#  'Liuzhangli',
#  'SANDBOX_Hollow',
#  'Need_time',
#  'Noisave',
#  'SANDBOX_Hollis',
#  'DWG_ShowMaker',
#  'Challenger1000LP',
#  'KZ_Cuzz',
#  'bydeinm',
#  'GgalChang',
#  'hide_in_bush',
#  'Joker_Mask',
#  'SANDBOX_JoKer',
#  'SKT_T1_M4A1_C',
#  'California_Life',
#  '20041024',
#  'summertime',
#  'Top_op_line',
#  'Secret',
#  'chuanzuodengban',
#  '4seidon',
#  '98_hwan',
#  'choleu71',
#  'tnedifnoc_syawla',
#  'clever1',
#  'shame_shame',
#  'mindie',
#  'Minato_Aqua',
#  'Dont_Stop_Me_XD',
#  'Lehends',
#  'hearer',
#  'yzdzh',
#  'LovelyAlly',
#  'Prdman',
#  'haje2',
#  'sda12dasda',
#  'H2O_Man',
#  'meiyoucaozuo',
#  'YourHead_OneShot',
#  'Tangwa1998',
#  '델몬트',
#  'Cuzz',
#  'SN_Ezsyboom',
#  'missyou_missyou2',
#  'riseee',
#  'meizijiaVX',
#  'Gen_G_Kuzan2',
#  'AOTG',
#  'Self_directed',
#  '061604091228',
#  'Lehends_heir',
#  'ApocalypseXD',
#  'FirstBible',
#  'snzll',
#  'MonyDay',
#  'simh',
#  'rai341']

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_DIAMOND" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 266, 'spell1Id': 12, 'spell2Id': 4, 'stats': {'participantId': 1, 'win': True, 'item0': 3044, 'item1': 1054, 'item2': 3133, 'item3': 3067, 'item4': 1001, 'item5': 0, 'item6': 3340, 'kills': 3, 'deaths': 1, 'assists': 4, 'largestKillingSpree': 3, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 687, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 60457, 'magicDamageDealt': 0, 'physicalDamageDealt': 56222, 'trueDamageDealt': 4235, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 6193, 'magicDamageDealtToChampions': 0, 'physicalDamageDealtToChampions': 6134, 'trueDamageDealtToChampions': 59, 'totalHeal': 6037, 'totalUnitsHealed': 1, 'damageSelfMitigated': 5798, 'damageDealtToObjectives': 9444, 'damageDealtToTurrets': 0, 'visionScore': 8, 'timeCCingOthers': 10, 'totalDamageTaken': 12524, 'magicalDamageTaken': 5700, 'physicalDamageTaken': 6798, 'trueDamageTaken': 25, 'goldEarned': 6226, 'goldSpent': 4100, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 115, 'neutralMinionsKilled': 8, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 4, 'totalTimeCrowdControlDealt': 97, 'champLevel': 11, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 6, 'wardsKilled': 0, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8010, 'perk0Var1': 59, 'perk0Var2': 32, 'perk0Var3': 103, 'perk1': 9111, 'perk1Var1': 457, 'perk1Var2': 140, 'perk1Var3': 0, 'perk2': 9105, 'perk2Var1': 14, 'perk2Var2': 20, 'perk2Var3': 0, 'perk3': 8299, 'perk3Var1': 154, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8139, 'perk4Var1': 334, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8135, 'perk5Var1': 930, 'perk5Var2': 5, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8100, 'statPerk0': 5008, 'statPerk1': 5008, 'statPerk2': 5002}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'0-10': 8.7}, 'xpPerMinDeltas': {'0-10': 475.59999999999997}, 'goldPerMinDeltas': {'0-10': 287.4}, 'csDiffPerMinDeltas': {'0-10': 0.02000000000000024}, 'xpDiffPerMinDeltas': {'0-10': 49.11999999999995}, 'damageTakenPerMinDeltas': {'0-10': 387.79999999999995}, 'damageTakenDiffPerMinDeltas': {'0-10': -58.56}, 'role': 'DUO', 'lane': 'NONE'}}, {'participantId': 2, 'teamId': 100, 'championId': 121, 'spell1Id': 11, 'spell2Id': 4, 'stats': {'participantId': 2, 'win': True, 'item0': 1412, 'item1': 2055, 'item2': 3117, 'item3': 1036, 'item4': 3134, 'item5': 0, 'item6': 3364, 'kills': 10, 'deaths': 3, 'assists': 2, 'largestKillingSpree': 3, 'largestMultiKill': 2, 'killingSprees': 4, 'longestTimeSpentLiving': 419, 'doubleKills': 2, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 66531, 'magicDamageDealt': 4939, 'physicalDamageDealt': 56333, 'trueDamageDealt': 5258, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 8892, 'magicDamageDealtToChampions': 575, 'physicalDamageDealtToChampions': 7908, 'trueDamageDealtToChampions': 408, 'totalHeal': 7376, 'totalUnitsHealed': 1, 'damageSelfMitigated': 6397, 'damageDealtToObjectives': 15313, 'damageDealtToTurrets': 1025, 'visionScore': 23, 'timeCCingOthers': 4, 'totalDamageTaken': 14784, 'magicalDamageTaken': 3140, 'physicalDamageTaken': 11252, 'trueDamageTaken': 392, 'goldEarned': 7395, 'goldSpent': 5050, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 7, 'neutralMinionsKilled': 64, 'neutralMinionsKilledTeamJungle': 33, 'neutralMinionsKilledEnemyJungle': 10, 'totalTimeCrowdControlDealt': 124, 'champLevel': 9, 'visionWardsBoughtInGame': 3, 'sightWardsBoughtInGame ...
# D점멸쓰는사람 0
# F점멸쓰는사람 13960

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_GOLD" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 81, 'spell1Id': 4, 'spell2Id': 7, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 1, 'win': False, 'item0': 2010, 'item1': 1055, 'item2': 3070, 'item3': 3025, 'item4': 0, 'item5': 2422, 'item6': 3340, 'kills': 2, 'deaths': 7, 'assists': 1, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'killingSprees': 0, 'longestTimeSpentLiving': 216, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 29045, 'magicDamageDealt': 4514, 'physicalDamageDealt': 24515, 'trueDamageDealt': 15, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 4878, 'magicDamageDealtToChampions': 1437, 'physicalDamageDealtToChampions': 3425, 'trueDamageDealtToChampions': 15, 'totalHeal': 693, 'totalUnitsHealed': 3, 'damageSelfMitigated': 4066, 'damageDealtToObjectives': 0, 'damageDealtToTurrets': 0, 'visionScore': 4, 'timeCCingOthers': 0, 'totalDamageTaken': 9438, 'magicalDamageTaken': 2583, 'physicalDamageTaken': 6855, 'trueDamageTaken': 0, 'goldEarned': 4969, 'goldSpent': 4150, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 71, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 43, 'champLevel': 8, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 3, 'wardsKilled': 1, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8359, 'perk0Var1': 460, 'perk0Var2': 10, 'perk0Var3': 0, 'perk1': 8304, 'perk1Var1': 10, 'perk1Var2': 3, 'perk1Var3': 0, 'perk2': 8345, 'perk2Var1': 4, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8347, 'perk3Var1': 0, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8226, 'perk4Var1': 250, 'perk4Var2': 180, 'perk4Var3': 0, 'perk5': 8210, 'perk5Var1': 0, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8300, 'perkSubStyle': 8200, 'statPerk0': 5005, 'statPerk1': 5008, 'statPerk2': 5001}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'0-10': 3.9}, 'xpPerMinDeltas': {'0-10': 287.8}, 'goldPerMinDeltas': {'0-10': 261.9}, 'csDiffPerMinDeltas': {'0-10': -0.2599999999999998}, 'xpDiffPerMinDeltas': {'0-10': 19.279999999999973}, 'damageTakenPerMinDeltas': {'0-10': 466.9}, 'damageTakenDiffPerMinDeltas': {'0-10': 155.83999999999995}, 'role': 'DUO_SUPPORT', 'lane': 'NONE'}}, {'participantId': 2, 'teamId': 100, 'championId': 4, 'spell1Id': 7, 'spell2Id': 4, 'highestAchievedSeasonTier': 'GOLD', 'stats': {'participantId': 2, 'win': False, 'item0': 3027, 'item1': 1082, 'item2': 2033, 'item3': 3009, 'item4': 0, 'item5': 0, 'item6': 3340, 'kills': 1, 'deaths': 4, 'assists': 1, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'killingSprees': 0, 'longestTimeSpentLiving': 500, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 53562, 'magicDamageDealt': 43868, 'physicalDamageDealt': 7619, 'trueDamageDealt': 2074, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 4251, 'magicDamageDealtToChampions': 3771, 'physicalDamageDealtToChampions': 479, 'trueDamageDealtToChampions': 0, 'totalHeal': 870, 'totalUnitsHealed': 1, 'damageSelfMitigated': 3419, 'damageDealtToObjectives': 0, 'damageDealtToTurrets': 0, 'visionScore': 12, 'timeCCingOthers': 9, 'totalDamageTaken': 10038, 'magicalDamageTaken': 3815, 'physicalDamageTaken': 5992, 'trueDamageTaken': 230, 'goldEarned': 5163, 'goldSpent': 4125, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 110, 'neutralMinionsKilled': 2, 'neutralMinionsKilledTeamJungle': 2, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 81, 'champLevel': 10, 'visionWardsB ...
# D점멸쓰는사람 8037
# F점멸쓰는사람 18753

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_PLATINUM" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 34, 'spell1Id': 12, 'spell2Id': 4, 'highestAchievedSeasonTier': 'PLATINUM', 'stats': {'participantId': 1, 'win': True, 'item0': 1056, 'item1': 2421, 'item2': 3070, 'item3': 3020, 'item4': 3027, 'item5': 3108, 'item6': 3340, 'kills': 4, 'deaths': 1, 'assists': 12, 'largestKillingSpree': 3, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 452, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 53115, 'magicDamageDealt': 44932, 'physicalDamageDealt': 7069, 'trueDamageDealt': 1112, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 14834, 'magicDamageDealtToChampions': 12972, 'physicalDamageDealtToChampions': 1143, 'trueDamageDealtToChampions': 718, 'totalHeal': 870, 'totalUnitsHealed': 1, 'damageSelfMitigated': 4291, 'damageDealtToObjectives': 3525, 'damageDealtToTurrets': 3525, 'visionScore': 12, 'timeCCingOthers': 33, 'totalDamageTaken': 11670, 'magicalDamageTaken': 3240, 'physicalDamageTaken': 7790, 'trueDamageTaken': 639, 'goldEarned': 8096, 'goldSpent': 6550, 'turretKills': 1, 'inhibitorKills': 1, 'totalMinionsKilled': 86, 'neutralMinionsKilled': 12, 'neutralMinionsKilledTeamJungle': 8, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 439, 'champLevel': 12, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 6, 'wardsKilled': 1, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': True, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8112, 'perk0Var1': 938, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8126, 'perk1Var1': 718, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8138, 'perk2Var1': 30, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8106, 'perk3Var1': 5, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8226, 'perk4Var1': 250, 'perk4Var2': 551, 'perk4Var3': 0, 'perk5': 8237, 'perk5Var1': 410, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8100, 'perkSubStyle': 8200, 'statPerk0': 5008, 'statPerk1': 5008, 'statPerk2': 5001}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'0-10': 5.4}, 'xpPerMinDeltas': {'0-10': 443.2}, 'goldPerMinDeltas': {'0-10': 289.5}, 'csDiffPerMinDeltas': {'0-10': 0.5399999999999998}, 'xpDiffPerMinDeltas': {'0-10': 43.05999999999996}, 'damageTakenPerMinDeltas': {'0-10': 409.7}, 'damageTakenDiffPerMinDeltas': {'0-10': -8.139999999999958}, 'role': 'DUO_SUPPORT', 'lane': 'NONE'}}, {'participantId': 2, 'teamId': 100, 'championId': 120, 'spell1Id': 6, 'spell2Id': 11, 'stats': {'participantId': 2, 'win': True, 'item0': 1401, 'item1': 2031, 'item2': 3078, 'item3': 3111, 'item4': 1036, 'item5': 0, 'item6': 3340, 'kills': 6, 'deaths': 3, 'assists': 2, 'largestKillingSpree': 6, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 967, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 112148, 'magicDamageDealt': 14016, 'physicalDamageDealt': 86542, 'trueDamageDealt': 11589, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 6286, 'magicDamageDealtToChampions': 1011, 'physicalDamageDealtToChampions': 4753, 'trueDamageDealtToChampions': 521, 'totalHeal': 7739, 'totalUnitsHealed': 1, 'damageSelfMitigated': 8326, 'damageDealtToObjectives': 28440, 'damageDealtToTurrets': 5886, 'visionScore': 12, 'timeCCingOthers': 11, 'totalDamageTaken': 17971, 'magicalDamageTaken': 4000, 'physicalDamageTaken': 12573, 'trueDamageTaken': 1397, 'goldEarned': 8710, 'goldSpent': 7908, 'turretKills': 2, 'inhibitorKills': 1, 'totalMinionsKilled': 16, 'neutralMinionsKilled': 88, 'neutralMinionsKilledTeamJungle': 54, 'neutralMinionsKilledEnemyJungle' ...
# D점멸쓰는사람 7872
# F점멸쓰는사람 9840

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_SILVER" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 266, 'spell1Id': 11, 'spell2Id': 4, 'stats': {'participantId': 1, 'win': False, 'item0': 1400, 'item1': 3065, 'item2': 3071, 'item3': 3812, 'item4': 3047, 'item5': 0, 'item6': 3340, 'kills': 5, 'deaths': 4, 'assists': 1, 'largestKillingSpree': 3, 'largestMultiKill': 1, 'killingSprees': 2, 'longestTimeSpentLiving': 1068, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 266565, 'magicDamageDealt': 9838, 'physicalDamageDealt': 243805, 'trueDamageDealt': 12922, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 6962, 'magicDamageDealtToChampions': 0, 'physicalDamageDealtToChampions': 6466, 'trueDamageDealtToChampions': 495, 'totalHeal': 20515, 'totalUnitsHealed': 1, 'damageSelfMitigated': 28484, 'damageDealtToObjectives': 34931, 'damageDealtToTurrets': 0, 'visionScore': 34, 'timeCCingOthers': 8, 'totalDamageTaken': 38083, 'magicalDamageTaken': 10751, 'physicalDamageTaken': 22874, 'trueDamageTaken': 4457, 'goldEarned': 13681, 'goldSpent': 13250, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 10, 'neutralMinionsKilled': 230, 'neutralMinionsKilledTeamJungle': 156, 'neutralMinionsKilledEnemyJungle': 28, 'totalTimeCrowdControlDealt': 315, 'champLevel': 17, 'visionWardsBoughtInGame': 1, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 13, 'wardsKilled': 1, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8010, 'perk0Var1': 0, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 9111, 'perk1Var1': 278, 'perk1Var2': 120, 'perk1Var3': 0, 'perk2': 9105, 'perk2Var1': 18, 'perk2Var2': 40, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 101, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8126, 'perk4Var1': 183, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8135, 'perk5Var1': 4188, 'perk5Var2': 4, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8100, 'statPerk0': 5005, 'statPerk1': 5008, 'statPerk2': 5002}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'10-20': 0.4, '0-10': 0.2, '30-end': 0, '20-30': 0.4}, 'xpPerMinDeltas': {'10-20': 438.1, '0-10': 324, '30-end': 408, '20-30': 575.4}, 'goldPerMinDeltas': {'10-20': 374.3, '0-10': 278.4, '30-end': 323.8, '20-30': 438.3}, 'csDiffPerMinDeltas': {'10-20': -0.6000000000000001, '0-10': 0, '30-end': -1.2, '20-30': -0.5999999999999999}, 'xpDiffPerMinDeltas': {'10-20': 162.79999999999998, '0-10': 62.79999999999998, '30-end': -239.60000000000002, '20-30': 161.49999999999997}, 'damageTakenPerMinDeltas': {'10-20': 983.9, '0-10': 766.1, '30-end': 1188.4, '20-30': 1053.1}, 'damageTakenDiffPerMinDeltas': {'10-20': 226.39999999999998, '0-10': 248.20000000000005, '30-end': 300.20000000000005, '20-30': 69.20000000000005}, 'role': 'NONE', 'lane': 'JUNGLE'}}, {'participantId': 2, 'teamId': 100, 'championId': 238, 'spell1Id': 14, 'spell2Id': 4, 'highestAchievedSeasonTier': 'GOLD', 'stats': {'participantId': 2, 'win': False, 'item0': 3142, 'item1': 3140, 'item2': 3814, 'item3': 3147, 'item4': 3026, 'item5': 3111, 'item6': 3363, 'kills': 11, 'deaths': 9, 'assists': 4, 'largestKillingSpree': 3, 'largestMultiKill': 2, 'killingSprees': 3, 'longestTimeSpentLiving': 510, 'doubleKills': 1, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 166308, 'magicDamageDealt': 7053, 'physicalDamageDealt': 150123, 'trueDamageDealt': 9131, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 29689, 'magicDamageDealtToChampions': 574, 'physicalDamageDealtToChampions': 28501, 'trueDamageDealtToChampions': 614, 'totalHeal': 2531, 'totalUnitsHealed': 1, 'damageSelfMitigated' ...
# D점멸쓰는사람 0
# F점멸쓰는사람 25320

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_BRONZE" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 82, 'spell1Id': 12, 'spell2Id': 4, 'highestAchievedSeasonTier': 'GOLD', 'stats': {'participantId': 1, 'win': True, 'item0': 1054, 'item1': 2003, 'item2': 3151, 'item3': 3020, 'item4': 3116, 'item5': 0, 'item6': 3340, 'kills': 8, 'deaths': 3, 'assists': 2, 'largestKillingSpree': 4, 'largestMultiKill': 3, 'killingSprees': 3, 'longestTimeSpentLiving': 336, 'doubleKills': 1, 'tripleKills': 1, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 68102, 'magicDamageDealt': 53241, 'physicalDamageDealt': 9236, 'trueDamageDealt': 5625, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 9815, 'magicDamageDealtToChampions': 7776, 'physicalDamageDealtToChampions': 1542, 'trueDamageDealtToChampions': 497, 'totalHeal': 4792, 'totalUnitsHealed': 1, 'damageSelfMitigated': 8144, 'damageDealtToObjectives': 4019, 'damageDealtToTurrets': 4019, 'visionScore': 13, 'timeCCingOthers': 8, 'totalDamageTaken': 13301, 'magicalDamageTaken': 7260, 'physicalDamageTaken': 5589, 'trueDamageTaken': 451, 'goldEarned': 8023, 'goldSpent': 7750, 'turretKills': 1, 'inhibitorKills': 0, 'totalMinionsKilled': 94, 'neutralMinionsKilled': 4, 'neutralMinionsKilledTeamJungle': 4, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 126, 'champLevel': 11, 'visionWardsBoughtInGame': 2, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 7, 'wardsKilled': 1, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8010, 'perk0Var1': 374, 'perk0Var2': 123, 'perk0Var3': 429, 'perk1': 9111, 'perk1Var1': 773, 'perk1Var2': 200, 'perk1Var3': 0, 'perk2': 9105, 'perk2Var1': 12, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 350, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8139, 'perk4Var1': 557, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8135, 'perk5Var1': 1834, 'perk5Var2': 4, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8100, 'statPerk0': 5008, 'statPerk1': 5008, 'statPerk2': 5001}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'0-10': 5.699999999999999}, 'xpPerMinDeltas': {'0-10': 454.5}, 'goldPerMinDeltas': {'0-10': 347.3}, 'csDiffPerMinDeltas': {'0-10': 1.4799999999999995}, 'xpDiffPerMinDeltas': {'0-10': 97.58000000000001}, 'damageTakenPerMinDeltas': {'0-10': 709.4}, 'damageTakenDiffPerMinDeltas': {'0-10': -100.47999999999996}, 'role': 'DUO_SUPPORT', 'lane': 'NONE'}}, {'participantId': 2, 'teamId': 100, 'championId': 60, 'spell1Id': 11, 'spell2Id': 4, 'highestAchievedSeasonTier': 'PLATINUM', 'stats': {'participantId': 2, 'win': True, 'item0': 1402, 'item1': 2031, 'item2': 2421, 'item3': 3165, 'item4': 3117, 'item5': 1052, 'item6': 3364, 'kills': 9, 'deaths': 3, 'assists': 11, 'largestKillingSpree': 5, 'largestMultiKill': 1, 'killingSprees': 2, 'longestTimeSpentLiving': 453, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 54146, 'magicDamageDealt': 35835, 'physicalDamageDealt': 15328, 'trueDamageDealt': 2983, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 12319, 'magicDamageDealtToChampions': 9488, 'physicalDamageDealtToChampions': 1340, 'trueDamageDealtToChampions': 1490, 'totalHeal': 3583, 'totalUnitsHealed': 1, 'damageSelfMitigated': 3797, 'damageDealtToObjectives': 2339, 'damageDealtToTurrets': 2339, 'visionScore': 11, 'timeCCingOthers': 39, 'totalDamageTaken': 10444, 'magicalDamageTaken': 4286, 'physicalDamageTaken': 6030, 'trueDamageTaken': 128, 'goldEarned': 8437, 'goldSpent': 7810, 'turretKills': 2, 'inhibitorKills': 0, 'totalMinionsKilled': 11, 'neutralMinionsKilled': 60, 'neutralMinionsKilledTeamJungle': 36, 'neutralMinionsKilledEnemyJungle': 12, ' ...
# D점멸쓰는사람 2168
# F점멸쓰는사람 17344

# %%
import os
import ast

directory = os.getcwd() + '/gamedata/'

data = set()

for file in os.listdir(directory):
    username = os.fsdecode(file)
    each_dir = os.path.join(directory, username)
    for file in os.listdir(each_dir):
        sub_filename = os.fsdecode(file)
        new_dir = directory + username + '/' + sub_filename
        if "_IRON" in new_dir:
            #print(new_dir)
            with open(new_dir, encoding="UTF-8") as f:
                single_data = f.readlines()
                for single_game in single_data:
                    data.add(single_game)
                    
        

dic_converted_data = []
gameid_list = []

# 5849/6555
for gamedata in data:
    example = ast.literal_eval(gamedata)
    gameid = example['gameId']

    if gameid not in gameid_list:
        gameid_list.append(gameid)
        dic_converted_data.append(example)

#print(len(gameid_list))
#print(len(dic_converted_data))
#print(gamedata)
example2=ast.literal_eval(gamedata)
game_data=example2.get('game_data')
participants=game_data.get('participants')
print (participants)

count1=0
count2=0

for j in dic_converted_data:
    for spell in participants:
        if spell['spell1Id'] == 4:
            count1=count1+1
        elif spell['spell2Id'] == 4:
            count2=count2+1

print("D점멸쓰는사람",count1)
print("F점멸쓰는사람",count2)
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 245, 'spell1Id': 4, 'spell2Id': 13, 'stats': {'participantId': 1, 'win': False, 'item0': 3020, 'item1': 0, 'item2': 3152, 'item3': 3089, 'item4': 3285, 'item5': 3100, 'item6': 2052, 'kills': 14, 'deaths': 9, 'assists': 18, 'largestKillingSpree': 4, 'largestMultiKill': 2, 'killingSprees': 4, 'longestTimeSpentLiving': 397, 'doubleKills': 2, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 124374, 'magicDamageDealt': 114345, 'physicalDamageDealt': 7289, 'trueDamageDealt': 2740, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 27177, 'magicDamageDealtToChampions': 24282, 'physicalDamageDealtToChampions': 2894, 'trueDamageDealtToChampions': 0, 'totalHeal': 13661, 'totalUnitsHealed': 1, 'damageSelfMitigated': 26868, 'damageDealtToObjectives': 569, 'damageDealtToTurrets': 569, 'visionScore': 0, 'timeCCingOthers': 13, 'totalDamageTaken': 37867, 'magicalDamageTaken': 24625, 'physicalDamageTaken': 11211, 'trueDamageTaken': 2030, 'goldEarned': 17099, 'goldSpent': 14850, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 112, 'neutralMinionsKilled': 0, 'totalTimeCrowdControlDealt': 240, 'champLevel': 18, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': True, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8112, 'perk0Var1': 1241, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8143, 'perk1Var1': 779, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8138, 'perk2Var1': 30, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8135, 'perk3Var1': 4557, 'perk3Var2': 4, 'perk3Var3': 0, 'perk4': 8233, 'perk4Var1': 8, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8236, 'perk5Var1': 80, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8100, 'perkSubStyle': 8200, 'statPerk0': 5008, 'statPerk1': 5008, 'statPerk2': 5003}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'10-20': 3.6999999999999997, '0-10': 4.300000000000001}, 'xpPerMinDeltas': {'10-20': 1032.5, '0-10': 738.9}, 'goldPerMinDeltas': {'10-20': 610.8, '0-10': 551.9000000000001}, 'damageTakenPerMinDeltas': {'10-20': 1609.9, '0-10': 637.4}, 'role': 'DUO', 'lane': 'TOP'}}, {'participantId': 2, 'teamId': 100, 'championId': 111, 'spell1Id': 7, 'spell2Id': 4, 'stats': {'participantId': 2, 'win': False, 'item0': 3193, 'item1': 3190, 'item2': 3050, 'item3': 0, 'item4': 3110, 'item5': 3029, 'item6': 0, 'kills': 4, 'deaths': 8, 'assists': 24, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'killingSprees': 0, 'longestTimeSpentLiving': 305, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 33069, 'magicDamageDealt': 26091, 'physicalDamageDealt': 6978, 'trueDamageDealt': 0, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 15394, 'magicDamageDealtToChampions': 12106, 'physicalDamageDealtToChampions': 3288, 'trueDamageDealtToChampions': 0, 'totalHeal': 8456, 'totalUnitsHealed': 4, 'damageSelfMitigated': 66852, 'damageDealtToObjectives': 0, 'damageDealtToTurrets': 0, 'visionScore': 0, 'timeCCingOthers': 72, 'totalDamageTaken': 32379, 'magicalDamageTaken': 22599, 'physicalDamageTaken': 7582, 'trueDamageTaken': 2197, 'goldEarned': 12997, 'goldSpent': 13350, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 22, 'neutralMinionsKilled': 0, 'totalTimeCrowdControlDealt': 524, 'champLevel': 18, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, ' ...
# D점멸쓰는사람 1096
# F점멸쓰는사람 4384
